# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load dataset
df = pd.read_csv("Cardiotocographic.csv")
df.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
# Dataset shape
df.shape
# Dataset structure and data types
df.info()
# Column names
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB
# Index(['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
#        'MLTV', 'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %%
#missing value
df.isnull().sum()
# Fill missing values with column mean
df.fillna(df.mean(), inplace=True)

# %%
df.duplicated().sum()
# Remove duplicates if any
df.drop_duplicates(inplace=True)

# %%
df.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2124.000000  2124.000000  2124.000000  2124.000000  2124.000000
# mean    133.342039     0.003220     0.009904     0.004394     0.001897
# std      11.212396     0.004371     0.067571     0.003340     0.003344
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001858     0.000000
# 50%     133.000000     0.001668     0.000000     0.004486     0.000000
# 75%     140.000000     0.005612     0.002568     0.006536     0.003292
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2124.000000  2124.000000  2124.000000  2124.000000  2124.000000
# mean      0.000003     0.000175    47.012459     1.364345    10.295650
# std       0.000141     0.000836    18.812403     1.174084    21.212676
# ...

# %%
# Median
df.median()
# Out:
# LB          133.000000
# AC            0.001668
# FM            0.000000
# UC            0.004486
# DL            0.000000
# DS            0.000000
# DP            0.000000
# ASTV         49.000000
# MSTV          1.200000
# ALTV          0.000000
# MLTV          7.500000
# Width        68.000000
# Tendency      0.000000
# NSP           1.000000
# dtype: float64

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# LB          14.000000
# AC           0.005612
# FM           0.002568
# UC           0.004678
# DL           0.003292
# DS           0.000000
# DP           0.000000
# ASTV        29.000000
# MSTV         1.000000
# ALTV        11.000000
# MLTV         6.200000
# Width       63.000000
# Tendency     1.000000
# NSP          0.000000
# dtype: float64

# %% [markdown]
# Findings:
#
# LB (Baseline FHR) values mostly lie in a normal clinical range.
#
# Variability-related features (ASTV, MSTV, ALTV, MLTV) show high dispersion.
#
# Presence of extreme values indicates possible fetal distress cases.

# %%
#outlier detection
plt.figure(figsize=(12,6))
sns.boxplot(data=df)
plt.xticks(rotation=90)
plt.title("Boxplot for Outlier Detection")
plt.show()

# %%
df.hist(figsize=(15,12), bins=30)
plt.suptitle("Histogram of Cardiotocographic Features")
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), cmap='coolwarm', annot=False)
plt.title("Correlation Heatmap")
plt.show()

# %%
# Pair plot using a sample
sns.pairplot(
    df.sample(300),
    diag_kind='kde'
)
plt.suptitle("Pair Plot of Cardiotocographic Features", y=1.02)
plt.show()
# Out:
# D:\New folder\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(10,5))
sns.violinplot(data=df[['ASTV', 'MSTV', 'ALTV', 'MLTV']])
plt.title("Violin Plot of Variability Features")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='NSP', data=df)
plt.title("Bar Chart of Fetal Health Categories")
plt.xlabel("Fetal Health Class")
plt.ylabel("Frequency")
plt.show()

# %% [raw]
# #Pattern Recognition and Insights:
#
# ASTV is negatively correlated with MSTV, indicating that increased abnormal short-term variability reduces healthy heart rate variability.
#
# ALTV shows a negative correlation with MLTV, suggesting impaired long-term fetal heart rate regulation.
#
# Uterine Contractions (UC) are positively correlated with Decelerations (DL, DP), implying that stronger or frequent contractions increase fetal stress.
#
# Baseline Fetal Heart Rate (LB) moderately correlates with variability features, affecting overall fetal condition.
#
# #Analysis:
#
# The dataset does not contain explicit temporal data, so direct time-based trend analysis is not possible.
#
# Repeated abnormal patterns indirectly suggest progressive fetal stress.

# %% [raw]
# #Conclusion
#
# The dataset contains rich clinical signals related to fetal well-being.
#
# Variability and deceleration features play a crucial role in diagnosis.
#
# Correlation analysis highlights important relationships for predictive modeling.
#
# This EDA forms a strong base for classification or risk prediction models in healthcare.
